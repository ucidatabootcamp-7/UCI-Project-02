# %%
# deletes engine - run when you have to restart
# !rm world_dev.sqlite

# %%
# sqlalchemy dependencies
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect
from sqlalchemy import func

from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float, Text, Numeric

import os

# %%
# pandas dependencies
import pandas as pd
import pandas_profiling

# display multiple print results on one line
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# flask 
from flask import Flask, jsonify

# %%
# read csv
df = pd.read_csv('data2.csv')
df.head()
# Out:
#    Unnamed: 0 IsoCode  CountryName                      Region  \
# 0           0     AFG  Afghanistan                  South Asia
# 1           1     ALB      Albania       Europe & Central Asia
# 2           2     DZA      Algeria  Middle East & North Africa
# 3           3     AGO       Angola          Sub-Saharan Africa
# 4           4     ATA   Antarctica                         NaN
#
#            IncomeGroup  GiniYear  GiniCoefficient  HomicideYear  \
# 0           Low income       NaN            38.62        2012.0
# 1  Upper middle income    2012.0            29.00        2015.0
# 2  Upper middle income    2011.0            27.60        2015.0
# 3  Lower middle income    2008.0            42.70        2015.0
# 4                  NaN       NaN            38.62           NaN
#
#    HomicidePer100k    HDI  GDP_Mean  LifeExpectancy  services2015  \
# 0              6.6  0.479  5.607081       63.298195     55.653409
# 1              0.0  0.764  2.293126       78.203146     52.962187
# 2              0.0  0.745  3.360144       75.855293     48.586545
# 3              0.0  0.533  3.777340       61.189341           NaN
# 4              NaN    NaN       NaN             NaN           NaN
#
#    industry2015  agriculture2015  GDP_PPP_Year       GDP_PPP
# 0     22.945869        21.400722        2016.0   1944.117005
# 1     24.180001        22.857812        2016.0  11540.025560
# 2     38.805527        12.607928        2016.0  15013.296380
# 3           NaN              NaN        2016.0   6454.135370
# 4           NaN              NaN           NaN           NaN

# %%
updated_df = df.rename(columns={"Unnamed: 0": "id"
                  })
updated_df.set_index("id").head()
updated_df.shape
# Out:
#    IsoCode  CountryName                      Region          IncomeGroup  \
# id
# 0      AFG  Afghanistan                  South Asia           Low income
# 1      ALB      Albania       Europe & Central Asia  Upper middle income
# 2      DZA      Algeria  Middle East & North Africa  Upper middle income
# 3      AGO       Angola          Sub-Saharan Africa  Lower middle income
# 4      ATA   Antarctica                         NaN                  NaN
#
#     GiniYear  GiniCoefficient  HomicideYear  HomicidePer100k    HDI  GDP_Mean  \
# id
# 0        NaN            38.62        2012.0              6.6  0.479  5.607081
# 1     2012.0            29.00        2015.0              0.0  0.764  2.293126
# 2     2011.0            27.60        2015.0              0.0  0.745  3.360144
# 3     2008.0            42.70        2015.0              0.0  0.533  3.777340
# 4        NaN            38.62           NaN              NaN    NaN       NaN
#
#     LifeExpectancy  services2015  industry2015  agriculture2015  GDP_PPP_Year  \
# id
# 0        63.298195     55.653409     22.945869        21.400722        2016.0
# 1        78.203146     52.962187     24.180001        22.857812        2016.0
# 2        75.855293     48.586545     38.805527        12.607928        2016.0
# 3        61.189341           NaN           NaN              NaN        2016.0
# 4              NaN           NaN           NaN              NaN           NaN
#
#          GDP_PPP
# id
# 0    1944.117005
# 1   11540.025560
# 2   15013.296380
# 3    6454.135370
# 4            NaN
# (177, 17)

# %%
# pandas profile report
pandas_profiling.ProfileReport(updated_df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>17 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>177 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>5.9% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>23.6 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>136.5 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>12 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_GDP_Mean"><code>GDP_Mean</code></a> has 6 / 3.4% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_GDP_Mean"><code>GDP_Mean</code></a> has 4 / 2.3% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_GDP_PPP"><code>GDP_PPP</code></a> has 12 / 6.8% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_GDP_PPP_Year"><code>GDP_PPP_Year</code></a> has 12 / 6.8% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_GiniYear"><code>GiniYear</code></a> has 28 / 15.8% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_HDI"><code>HDI</code></a> has 12 / 6.8% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_HomicidePer100k"><code>HomicidePer100k</code></a> has 8 / 4.5% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_HomicidePer100k"><code>HomicidePer100k</code></a> has 132 / 74.6% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_HomicideYear"><code>HomicideYear</code></a> has 8 / 4.5% missing values <span class="label label-defaul

# %%
# create sqlite database
engine = create_engine("sqlite:///world_dev.sqlite")
conn = engine.connect()

# %%
# declarative_base
# Base = declarative_base()
Base = automap_base()

# %%
# create world_dev metadata class
class world_dev(Base):
    __tablename__ = 'world_dev'
    
    id = Column(Integer, primary_key=True)
    IsoCode = Column(Text(64))
    CountryName = Column(Text(64))
    Region = Column(Text(64))
    IncomeGroup = Column(Text(64))
    GiniYear = Column(Float(64))
    GiniCoefficient = Column(Float(64))
    HomicideYear = Column(Float(64))
    HomicidePer100k = Column(Float(64))
    HDI = Column(Float(64))
    GDP_Mean = Column(Float(64))
    LifeExpectancy = Column(Float(64))
    services2015 = Column(Float(64))
    industry2015 = Column(Float(64))
    agriculture2015 = Column(Float(64))
    GDP_PPP_Year = Column(Float(64))
    GDP_PPP = Column(Float(64))
    
    def __repr__(self):
        return f"id={self.ID}"

# %%
# create a "metadata" layer that abstracts our SQL Database
Base.metadata.create_all(engine)
engine.table_names()
# Out:
# ['world_dev']

# %%
# create a session object to connect to DB
session = Session(bind=engine)

# %%
# add updated_df csv data
updated_df.to_sql('world_dev', conn, if_exists='append', index=False)

# %%
# read back world_dev class to see if updated_df data was appended to world_dev.sqlite
data_world_dev = pd.read_sql("SELECT * FROM world_dev", conn)
# data_world_dev.head()
# data_world_dev.tail()
data_world_dev.shape
# Out:
# (177, 17)

# %%
# store data_world_dev into new variable and set index to id
final_sql_df = data_world_dev.set_index('id')
final_sql_df.head()
# Out:
#    IsoCode  CountryName                      Region          IncomeGroup  \
# id
# 0      AFG  Afghanistan                  South Asia           Low income
# 1      ALB      Albania       Europe & Central Asia  Upper middle income
# 2      DZA      Algeria  Middle East & North Africa  Upper middle income
# 3      AGO       Angola          Sub-Saharan Africa  Lower middle income
# 4      ATA   Antarctica                        None                 None
#
#     GiniYear  GiniCoefficient  HomicideYear  HomicidePer100k    HDI  GDP_Mean  \
# id
# 0        NaN            38.62        2012.0              6.6  0.479  5.607081
# 1     2012.0            29.00        2015.0              0.0  0.764  2.293126
# 2     2011.0            27.60        2015.0              0.0  0.745  3.360144
# 3     2008.0            42.70        2015.0              0.0  0.533  3.777340
# 4        NaN            38.62           NaN              NaN    NaN       NaN
#
#     LifeExpectancy  services2015  industry2015  agriculture2015  GDP_PPP_Year  \
# id
# 0        63.298195     55.653409     22.945869        21.400722        2016.0
# 1        78.203146     52.962187     24.180001        22.857812        2016.0
# 2        75.855293     48.586545     38.805527        12.607928        2016.0
# 3        61.189341           NaN           NaN              NaN        2016.0
# 4              NaN           NaN           NaN              NaN           NaN
#
#          GDP_PPP
# id
# 0    1944.117005
# 1   11540.025560
# 2   15013.296380
# 3    6454.135370
# 4            NaN

# %%
# save to csv

# final_sql_df.to_csv('worldDev.csv')

# this sheet stores the avg gini inserted in place of null
final_sql_df.to_csv('worldDev2.csv')

# %%
# create object for worldDev.csv
#worldDevcsv = 'worldDev.csv'

# using the worldDev2csv that replaced null gini with the avg gini
worldDevcsv = 'worldDev2.csv'

# %%
# function to populate table
def populate_table (engine, table, csvfile):
    """Populates a table from a Pandas DataFrame."""
    
    # connect to the database
    conn = engine.connect()
    
    # Load the CSV file into a pandas dataframe
    insert_df = pd.read_csv(csvfile)
    
    # Orient='records' creates a list of data to write
    # http://pandas-docs.github.io/pandas-docs-travis/io.html#orient-options
    data = insert_df.to_dict(orient='records')
    print(data[:1])
    
    # Optional: Delete all rows in the table 
    conn.execute(table.delete())

    # Insert the dataframe into the database in one bulk insert
    conn.execute(table.insert(), data)

# %%
# Call the function to insert the data for each table
# world_dev is the class
populate_table(engine, world_dev.__table__, worldDevcsv)
# Out:
# [{'id': 0, 'IsoCode': 'AFG', 'CountryName': 'Afghanistan', 'Region': 'South Asia', 'IncomeGroup': 'Low income', 'GiniYear': nan, 'GiniCoefficient': 38.62, 'HomicideYear': 2012.0, 'HomicidePer100k': 6.6, 'HDI': 0.479, 'GDP_Mean': 5.60708087, 'LifeExpectancy': 63.29819512, 'services2015': 55.65340878, 'industry2015': 22.94586918, 'agriculture2015': 21.40072204, 'GDP_PPP_Year': 2016.0, 'GDP_PPP': 1944.117005}]

# %%
# check to see if data was added to table
engine.execute("SELECT * FROM world_Dev LIMIT 1").fetchall()
# Out:
# [(0, 'AFG', 'Afghanistan', 'South Asia', 'Low income', None, 38.62, 2012.0, 6.6, 0.479, 5.60708087, 63.29819512, 55.65340878, 22.94586918, 21.40072204, 2016.0, 1944.117005)]

# %% [markdown]
# ### End Database Engineering Section
# <br>
# <hr>

# %% [markdown]
# ### Reflect Table Section
# <hr>

# %%
# Use SQLAlchemy automap_base() to refelct tables into classes and save a reference to those classes
Base = automap_base()

# %%
# use the base class to reflect the database tables
Base.prepare(engine, reflect=True)

# %%
# print all of the classes mapped to the Base
Base.classes.keys()
# Out:
# ['world_dev']

# %%
# assign worldDev class to variables
WorldDev = Base.classes.world_dev

# %%
# create a session
session = Session(engine)

# %%
# Display the row's columns and data in dict format
results = session.query(WorldDev.CountryName, WorldDev.GiniCoefficient).all()

# %%
# Prints Country Name and GiniCoefficient
results
# Out:
# [('Afghanistan', 38.62),
#  ('Albania', 29.0),
#  ('Algeria', 27.6),
#  ('Angola', 42.7),
#  ('Antarctica', 38.62),
#  ('Argentina', 42.7),
#  ('Armenia', 32.4),
#  ('Australia', 34.7),
#  ('Austria', 30.5),
#  ('Azerbaijan', 31.8),
#  ('Bahamas', 38.62),
#  ('Bangladesh', 32.1),
#  ('Belarus', 26.7),
#  ('Belgium', 28.1),
#  ('Belize', 53.3),
#  ('Benin', 47.8),
#  ('Bermuda', 38.62),
#  ('Bhutan', 38.8),
#  ('Bolivia', 45.8),
#  ('Bosnia and Herzegovina', 33.8),
#  ('Botswana', 60.5),
#  ('Brazil', 51.3),
#  ('Brunei Darussalam', 38.62),
#  ('Bulgaria', 37.4),
#  ('Burkina Faso', 35.3),
#  ('Burundi', 39.2),
#  ('Cambodia', 38.62),
#  ('Cameroon', 46.5),
#  ('Canada', 34.0),
#  ('Central African Republic', 56.2),
#  ('Chad', 43.3),
#  ('Chile', 47.7),
#  ('China', 42.2),
#  ('Colombia', 51.1),
#  ('Congo\xa0(Brazzaville)', 48.9),
#  ('Congo, (Kinshasa)', 42.1),
#  ('Costa Rica', 48.2),
#  ("Côte d'Ivoire", 41.7),
#  ('Croatia', 32.2),
#  ('Cuba', 38.62),
#  ('Cyprus', 35.6),
#  ('Czech Republic', 25.9),
#  ('Denmark', 28.5),
#  ('Djibouti', 44.1),
#  ('Dominican Republic', 44.9),
#  ('Ecuador', 46.5),
#  ('Egypt', 31.8),
#  ('El Salvador', 40.8),
#  ('Equatorial Guinea', 38.62),
#  ('Eritrea', 38.62),
#  ('Estonia', 34.6),
#  ('Ethiopia', 33.2),
#  ('Falkland Islands (Malvinas)', 38.62),
#  ('Fiji', 36.4),
#  ('Finland', 26.8),
#  ('France', 32.3),
#  ('French Guiana', 38.62),
#  ('French Southern Territories', 38.62),
#  ('Gabon', 42.2),
#  ('Gambia', 47.3),
#  ('Georgia', 38.5),
#  ('Germany', 31.4),
#  ('Ghana', 42.2),
#  ('Greece', 35.8),
#  ('Greenland', 38.62),
#  ('Guatemala', 48.7),
#  ('Guinea', 33.7),
#  ('Guinea-Bissau', 50.7),
#  ('Guyana', 44.5),
#  ('Haiti', 40.9),
#  ('Honduras', 50.1),
#  ('Hungary', 30.9),
#  ('Iceland', 25.6),
#  ('India', 35.2),
#  ('Indonesia', 39.5),
#  ('Iran, Islamic Republic of', 38.8),
#  ('Iraq', 29.5),
#  ('Ireland', 31.9),
#  ('Israel', 41.4),
#  ('Italy', 34.7),
#  ('Jamaica', 45.5),
#  ('Japan', 32.1),
#  ('Jordan', 33.7),
#  ('Kazakhstan', 26.5),
#  ('Kenya', 48.5),
#  ('Korea\xa0(North)', 38.62),
#  ('Korea\xa0(South)', 31.6),
#  ('Kuwait', 38.62),
#  ('Kyrgyzstan', 29.0),
#  ('Lao PDR', 36.4),
#  ('Latvia', 35.1),
#  ('Lebanon', 31.8),
#  ('Lesotho', 54.2),
#  ('Liberia', 33.2),
#  ('Libya', 38.62),
#  ('Lithuania', 37.7),
#  ('Luxembourg', 31.2),
#  ('Macedonia, Republic of', 35.6),
#  ('Madagascar', 42.7),
#  ('Malawi', 46.1),
#  ('Malaysia', 46.3),
#  ('Mali', 33.0),
#  ('Malta', 38.62),
#  ('Mauritania', 32.4),
#  ('Mexico', 48.2),
#  ('Moldova', 27.0),
#  ('Mongolia', 32.0),
#  ('Montenegro', 31.9),
#  ('Morocco', 40.7),
#  ('Mozambique', 45.6),
#  ('Myanmar', 38.1),
#  ('Namibia', 61.0),
#  ('Nepal', 32.8),
#  ('Netherlands', 28.6),
#  ('New Caledonia', 38.62),
#  ('New Zealand', 38.62),
#  ('Nicaragua', 46.6),
#  ('Niger', 34.0),
#  ('Nigeria', 43.0),
#  ('Norway', 26.8),
#  ('Oman', 38.62),
#  ('Pakistan', 30.7),
#  ('Palestinian Territory', 34.4),
#  ('Panama', 51.0),
#  ('Papua New Guinea', 41.8),
#  ('Paraguay', 48.0),
#  ('Peru', 44.3),
#  ('Philippines', 40.1),
#  ('Poland', 32.1),
#  ('Portugal', 35.6),
#  ('Puerto Rico', 38.62),
#  ('Qatar', 38.62),
#  ('Romania', 27.5),
#  ('Russian Federation', 37.7),
#  ('Rwanda', 50.4),
#  ('Saudi Arabia', 38.62),
#  ('Senegal', 40.3),
#  ('Serbia', 29.1),
#  ('Sierra Leone', 34.0),
#  ('Slovakia', 26.1),
#  ('Slovenia', 25.7),
#  ('Solomon Islands', 37.0),
#  ('Somalia', 38.62),
#  ('South Africa', 63.4),
#  ('South Sudan', 46.3),
#  ('Spain', 36.0),
#  ('Sri Lanka', 39.2),
#  ('Sudan', 35.4),
#  ('Suriname', 57.6),
#  ('Swaziland', 51.5),
#  ('Sweden', 27.2),
#  ('Switzerland', 32.5),
#  ('Syrian Arab Republic\xa0(Syria)', 35.8),
#  ('Taiwan, Republic of China', 38.62),
#  ('Tajikistan', 34.0),
#  ('Tanzania, United Republic of', 37.8),
#  ('Thailand', 37.8),
#  ('Timor-Leste', 30.3),
#  ('Togo', 43.0),
#  ('Trinidad and Tobago', 38.62),
#  ('Tunisia', 35.8),
#  ('Turkey', 41.2),
#  ('Turkmenistan', 40.8),
#  ('Uganda', 41.0),
#  ('Ukraine', 25.5),
#  ('United Arab Emirates', 38.62),
#  ('United Kingdom', 34.1),
#  ('United States of America', 41.0),
#  ('Uruguay', 41.7),
#  ('Uzbekistan', 35.3),
#  ('Vanuatu', 37.3),
#  ('Venezuela\xa0(Bolivarian Republic)', 46.9),
#  ('Viet Nam', 34.8),
#  ('Western Sahara', 38.62),
#  ('Yemen', 36.7),
#  ('Zambia', 57.1),
#  ('Zimbabwe', 43.2)]

# %% [markdown]
# ### New Section

# %%
metadata_df1 = pd.read_csv('worldDev2.csv')
metadata_df1.head()
# Out:
#    id IsoCode  CountryName                      Region          IncomeGroup  \
# 0   0     AFG  Afghanistan                  South Asia           Low income
# 1   1     ALB      Albania       Europe & Central Asia  Upper middle income
# 2   2     DZA      Algeria  Middle East & North Africa  Upper middle income
# 3   3     AGO       Angola          Sub-Saharan Africa  Lower middle income
# 4   4     ATA   Antarctica                         NaN                  NaN
#
#    GiniYear  GiniCoefficient  HomicideYear  HomicidePer100k    HDI  GDP_Mean  \
# 0       NaN            38.62        2012.0              6.6  0.479  5.607081
# 1    2012.0            29.00        2015.0              0.0  0.764  2.293126
# 2    2011.0            27.60        2015.0              0.0  0.745  3.360144
# 3    2008.0            42.70        2015.0              0.0  0.533  3.777340
# 4       NaN            38.62           NaN              NaN    NaN       NaN
#
#    LifeExpectancy  services2015  industry2015  agriculture2015  GDP_PPP_Year  \
# 0       63.298195     55.653409     22.945869        21.400722        2016.0
# 1       78.203146     52.962187     24.180001        22.857812        2016.0
# 2       75.855293     48.586545     38.805527        12.607928        2016.0
# 3       61.189341           NaN           NaN              NaN        2016.0
# 4             NaN           NaN           NaN              NaN           NaN
#
#         GDP_PPP
# 0   1944.117005
# 1  11540.025560
# 2  15013.296380
# 3   6454.135370
# 4           NaN

# %%
metadata_df2.head()
# Out:
#              id IsoCode                      Region          IncomeGroup  \
# CountryName
# Afghanistan   0     AFG                  South Asia           Low income
# Albania       1     ALB       Europe & Central Asia  Upper middle income
# Algeria       2     DZA  Middle East & North Africa  Upper middle income
# Angola        3     AGO          Sub-Saharan Africa  Lower middle income
# Antarctica    4     ATA                         NaN                  NaN
#
#              GiniYear  GiniCoefficient  HomicideYear  HomicidePer100k    HDI  \
# CountryName
# Afghanistan       NaN            38.62        2012.0              6.6  0.479
# Albania        2012.0            29.00        2015.0              0.0  0.764
# Algeria        2011.0            27.60        2015.0              0.0  0.745
# Angola         2008.0            42.70        2015.0              0.0  0.533
# Antarctica        NaN            38.62           NaN              NaN    NaN
#
#              GDP_Mean  LifeExpectancy  services2015  industry2015  \
# CountryName
# Afghanistan  5.607081       63.298195     55.653409     22.945869
# Albania      2.293126       78.203146     52.962187     24.180001
# Algeria      3.360144       75.855293     48.586545     38.805527
# Angola       3.777340       61.189341           NaN           NaN
# Antarctica        NaN             NaN           NaN           NaN
#
#              agriculture2015  GDP_PPP_Year       GDP_PPP
# CountryName
# Afghanistan        21.400722        2016.0   1944.117005
# Albania            22.857812        2016.0  11540.025560
# Algeria            12.607928        2016.0  15013.296380
# Angola                   NaN        2016.0   6454.135370
# Antarctica               NaN           NaN           NaN

# %%
# create a variable country and set it equal to an input value
# here we use Afghanistan as a place holder
country = "Afghanistan"
country
# Out:
# 'Afghanistan'

# %%
countryID = metadata_df2.loc[country]
countryID
# Out:
# id                          0
# IsoCode                   AFG
# Region             South Asia
# IncomeGroup        Low income
# GiniYear                  NaN
# GiniCoefficient         38.62
# HomicideYear             2012
# HomicidePer100k           6.6
# HDI                     0.479
# GDP_Mean              5.60708
# LifeExpectancy        63.2982
# services2015          55.6534
# industry2015          22.9459
# agriculture2015       21.4007
# GDP_PPP_Year             2016
# GDP_PPP               1944.12
# Name: Afghanistan, dtype: object

# %%
unemployment_df = pd.read_csv('unemployment.csv')
unemployment_df.head()
unemployment_df.shape
# Out:
#    CountryName IsoCode  2015  2016  2017
# 0  Afghanistan     AFG   8.6   8.6   8.5
# 1      Albania     ALB  17.1  15.2  15.0
# 2      Algeria     DZA  11.2  11.5  11.7
# 3       Angola     AGO   6.2   6.1   6.2
# 4   Antarctica     ATA   NaN   NaN   NaN
# (177, 5)
